# %%
import pandas as pd

# %%
# Upload data from my data folder
pop = pd.read_csv('../../data/Pop_Den/Pop_Den.csv')

# %% [markdown]
# # shape of the data

# %%
pop.shape
# Out:
# (58, 58)

# %%
pop.head()
# Out:
#    Geo_FIPS     Geo_GEOID          Geo_NAME                     Geo_QName  \
# 0      6001  05000US06001    Alameda County    Alameda County, California
# 1      6003  05000US06003     Alpine County     Alpine County, California
# 2      6005  05000US06005     Amador County     Amador County, California
# 3      6007  05000US06007      Butte County      Butte County, California
# 4      6009  05000US06009  Calaveras County  Calaveras County, California
#
#   Geo_STUSAB  Geo_SUMLEV  Geo_GEOCOMP Geo_FILEID  Geo_LOGRECNO  Geo_US  ...  \
# 0         ca          50            0      ACSSF            13     NaN  ...
# 1         ca          50            0      ACSSF            14     NaN  ...
# 2         ca          50            0      ACSSF            15     NaN  ...
# 3         ca          50            0      ACSSF            16     NaN  ...
# 4         ca          50            0      ACSSF            17     NaN  ...
#
# ...

# %% [markdown]
# # see all the columns

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
pop.head()
# Out:
#    Geo_FIPS     Geo_GEOID          Geo_NAME                     Geo_QName  \
# 0      6001  05000US06001    Alameda County    Alameda County, California
# 1      6003  05000US06003     Alpine County     Alpine County, California
# 2      6005  05000US06005     Amador County     Amador County, California
# 3      6007  05000US06007      Butte County      Butte County, California
# 4      6009  05000US06009  Calaveras County  Calaveras County, California
#
#   Geo_STUSAB  Geo_SUMLEV  Geo_GEOCOMP Geo_FILEID  Geo_LOGRECNO  Geo_US  \
# 0         ca          50            0      ACSSF            13     NaN
# 1         ca          50            0      ACSSF            14     NaN
# 2         ca          50            0      ACSSF            15     NaN
# 3         ca          50            0      ACSSF            16     NaN
# 4         ca          50            0      ACSSF            17     NaN
#
#    Geo_REGION  Geo_DIVISION  Geo_STATECE  Geo_STATE  Geo_COUNTY  Geo_COUSUB  \
# ...

# %% [markdown]
# # see what data type

# %%
pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 58 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Geo_FIPS       58 non-null     int64
#  1   Geo_GEOID      58 non-null     object
#  2   Geo_NAME       58 non-null     object
#  3   Geo_QName      58 non-null     object
#  4   Geo_STUSAB     58 non-null     object
#  5   Geo_SUMLEV     58 non-null     int64
#  6   Geo_GEOCOMP    58 non-null     int64
#  7   Geo_FILEID     58 non-null     object
#  8   Geo_LOGRECNO   58 non-null     int64
#  9   Geo_US         0 non-null      float64
#  10  Geo_REGION     0 non-null      float64
#  11  Geo_DIVISION   0 non-null      float64
#  12  Geo_STATECE    0 non-null      float64
#  13  Geo_STATE      58 non-null     int64
#  14  Geo_COUNTY     58 non-null     int64
#  15  Geo_COUSUB     0 non-null      float64
#  16  Geo_PLACE      0 non-null      float64
# ...

# %%
pop.sample()
# Out:
#     Geo_FIPS     Geo_GEOID     Geo_NAME                Geo_QName Geo_STUSAB  \
# 16      6033  05000US06033  Lake County  Lake County, California         ca
#
#     Geo_SUMLEV  Geo_GEOCOMP Geo_FILEID  Geo_LOGRECNO  Geo_US  Geo_REGION  \
# 16          50            0      ACSSF            29     NaN         NaN
#
#     Geo_DIVISION  Geo_STATECE  Geo_STATE  Geo_COUNTY  Geo_COUSUB  Geo_PLACE  \
# 16           NaN          NaN          6          33         NaN        NaN
#
#     Geo_PLACESE  Geo_TRACT  Geo_BLKGRP  Geo_CONCIT  Geo_AIANHH  Geo_AIANHHFP  \
# 16          NaN        NaN         NaN         NaN         NaN           NaN
#
#     Geo_AIHHTLI  Geo_AITSCE  Geo_AITS  Geo_ANRC  Geo_CBSA  Geo_CSA  \
# 16          NaN         NaN       NaN       NaN       NaN      NaN
#
#     Geo_METDIV  Geo_MACC  Geo_MEMI  Geo_NECTA  Geo_CNECTA  Geo_NECTADIV  \
# 16         NaN       NaN       NaN        NaN         NaN           NaN
#
# ...

# %% [markdown]
# # check fips

# %%
pop.Geo_FIPS.head()
# Out:
# 0    6001
# 1    6003
# 2    6005
# 3    6007
# 4    6009
# Name: Geo_FIPS, dtype: int64

# %% [markdown]
# FIPS in CA should have floating zero.

# %% [markdown]
# # Put in leading zero
# All of these are in California obviously so there needs to be a 06. Will import the FIPS, state, and county as string instead of int64 so they have the leading zero

# %%
pop = pd.read_csv(
    '../../data/Pop_Den/Pop_Den.csv',
    dtype=
    {
        'Geo_FIPS':str,
        'Geo_STATE':str,
        'Geo_COUNTY': str
    }
)

# %%
pop.head()
# Out:
#   Geo_FIPS     Geo_GEOID          Geo_NAME                     Geo_QName  \
# 0    06001  05000US06001    Alameda County    Alameda County, California
# 1    06003  05000US06003     Alpine County     Alpine County, California
# 2    06005  05000US06005     Amador County     Amador County, California
# 3    06007  05000US06007      Butte County      Butte County, California
# 4    06009  05000US06009  Calaveras County  Calaveras County, California
#
#   Geo_STUSAB  Geo_SUMLEV  Geo_GEOCOMP Geo_FILEID  Geo_LOGRECNO  Geo_US  \
# 0         ca          50            0      ACSSF            13     NaN
# 1         ca          50            0      ACSSF            14     NaN
# 2         ca          50            0      ACSSF            15     NaN
# 3         ca          50            0      ACSSF            16     NaN
# 4         ca          50            0      ACSSF            17     NaN
#
#    Geo_REGION  Geo_DIVISION  Geo_STATECE Geo_STATE Geo_COUNTY  Geo_COUSUB  \
# ...

# %%
pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 58 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Geo_FIPS       58 non-null     object
#  1   Geo_GEOID      58 non-null     object
#  2   Geo_NAME       58 non-null     object
#  3   Geo_QName      58 non-null     object
#  4   Geo_STUSAB     58 non-null     object
#  5   Geo_SUMLEV     58 non-null     int64
#  6   Geo_GEOCOMP    58 non-null     int64
#  7   Geo_FILEID     58 non-null     object
#  8   Geo_LOGRECNO   58 non-null     int64
#  9   Geo_US         0 non-null      float64
#  10  Geo_REGION     0 non-null      float64
#  11  Geo_DIVISION   0 non-null      float64
#  12  Geo_STATECE    0 non-null      float64
#  13  Geo_STATE      58 non-null     object
#  14  Geo_COUNTY     58 non-null     object
#  15  Geo_COUSUB     0 non-null      float64
#  16  Geo_PLACE      0 non-null      float64
# ...

# %% [markdown]
# # get rid of empty columns
# Lots of columns where they are completely empty. Will get rid of them because there are really only four important ones: county, total population, population density, and land area.

# %%
pop.columns[pop.isna().all()].tolist()
# Out:
# ['Geo_US',
#  'Geo_REGION',
#  'Geo_DIVISION',
#  'Geo_STATECE',
#  'Geo_COUSUB',
#  'Geo_PLACE',
#  'Geo_PLACESE',
#  'Geo_TRACT',
#  'Geo_BLKGRP',
#  'Geo_CONCIT',
#  'Geo_AIANHH',
#  'Geo_AIANHHFP',
#  'Geo_AIHHTLI',
#  'Geo_AITSCE',
#  'Geo_AITS',
#  'Geo_ANRC',
#  'Geo_CBSA',
#  'Geo_CSA',
#  'Geo_METDIV',
#  'Geo_MACC',
#  'Geo_MEMI',
#  'Geo_NECTA',
#  'Geo_CNECTA',
#  'Geo_NECTADIV',
#  'Geo_UA',
#  'Geo_UACP',
#  'Geo_CDCURR',
#  'Geo_SLDU',
#  'Geo_SLDL',
#  'Geo_VTD',
#  'Geo_ZCTA3',
#  'Geo_ZCTA5',
#  'Geo_SUBMCD',
#  'Geo_SDELM',
#  'Geo_SDSEC',
#  'Geo_SDUNI',
#  'Geo_UR',
#  'Geo_PCI',
#  'Geo_TAZ',
#  'Geo_UGA',
#  'Geo_BTTR',
#  'Geo_BTBG',
#  'Geo_PUMA5',
#  'Geo_PUMA1']

# %%
pop = pop.dropna(axis=1,how="all")

# %%
pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Geo_FIPS       58 non-null     object
#  1   Geo_GEOID      58 non-null     object
#  2   Geo_NAME       58 non-null     object
#  3   Geo_QName      58 non-null     object
#  4   Geo_STUSAB     58 non-null     object
#  5   Geo_SUMLEV     58 non-null     int64
#  6   Geo_GEOCOMP    58 non-null     int64
#  7   Geo_FILEID     58 non-null     object
#  8   Geo_LOGRECNO   58 non-null     int64
#  9   Geo_STATE      58 non-null     object
#  10  Geo_COUNTY     58 non-null     object
#  11  SE_A00002_001  58 non-null     int64
#  12  SE_A00002_002  58 non-null     float64
#  13  SE_A00002_003  58 non-null     float64
# dtypes: float64(2), int64(4), object(8)
# memory usage: 6.5+ KB

# %%
pop.head()
# Out:
#   Geo_FIPS     Geo_GEOID          Geo_NAME                     Geo_QName  \
# 0    06001  05000US06001    Alameda County    Alameda County, California
# 1    06003  05000US06003     Alpine County     Alpine County, California
# 2    06005  05000US06005     Amador County     Amador County, California
# 3    06007  05000US06007      Butte County      Butte County, California
# 4    06009  05000US06009  Calaveras County  Calaveras County, California
#
#   Geo_STUSAB  Geo_SUMLEV  Geo_GEOCOMP Geo_FILEID  Geo_LOGRECNO Geo_STATE  \
# 0         ca          50            0      ACSSF            13        06
# 1         ca          50            0      ACSSF            14        06
# 2         ca          50            0      ACSSF            15        06
# 3         ca          50            0      ACSSF            16        06
# 4         ca          50            0      ACSSF            17        06
#
#   Geo_COUNTY  SE_A00002_001  SE_A00002_002  SE_A00002_003
# ...

# %%
pop.sample(5)
# Out:
#    Geo_FIPS     Geo_GEOID          Geo_NAME                     Geo_QName  \
# 10    06021  05000US06021      Glenn County      Glenn County, California
# 48    06097  05000US06097     Sonoma County     Sonoma County, California
# 3     06007  05000US06007      Butte County      Butte County, California
# 32    06065  05000US06065  Riverside County  Riverside County, California
# 44    06089  05000US06089     Shasta County     Shasta County, California
#
#    Geo_STUSAB  Geo_SUMLEV  Geo_GEOCOMP Geo_FILEID  Geo_LOGRECNO Geo_STATE  \
# 10         ca          50            0      ACSSF            23        06
# 48         ca          50            0      ACSSF            61        06
# 3          ca          50            0      ACSSF            16        06
# 32         ca          50            0      ACSSF            45        06
# 44         ca          50            0      ACSSF            57        06
#
#    Geo_COUNTY  SE_A00002_001  SE_A00002_002  SE_A00002_003
# ...

# %% [markdown]
# # eliminate redundant columns

# %%
col_drop = ['Geo_QName','Geo_STUSAB','Geo_GEOCOMP','Geo_FILEID','Geo_STATE']

# %%
pop = pop.drop(col_drop, axis = 1)

# %%
pop.head()
# Out:
#   Geo_FIPS     Geo_GEOID          Geo_NAME  Geo_SUMLEV  Geo_LOGRECNO  \
# 0    06001  05000US06001    Alameda County          50            13
# 1    06003  05000US06003     Alpine County          50            14
# 2    06005  05000US06005     Amador County          50            15
# 3    06007  05000US06007      Butte County          50            16
# 4    06009  05000US06009  Calaveras County          50            17
#
#   Geo_COUNTY  SE_A00002_001  SE_A00002_002  SE_A00002_003
# 0        001        1643700     2229.35100     737.299923
# 1        003           1146        1.55213     738.340335
# 2        005          37829       63.62395     594.571700
# 3        007         227075      138.75900    1636.470186
# 4        009          45235       44.34734    1020.015969

# %% [markdown]
# # Rename columns
# Making a list of the column names as they are in the dataset currently so I can copy and paste with what they actually mean, as determined by the data dictionary.

# %%
columns = list(pop)

# %%
columns
# Out:
# ['Geo_FIPS',
#  'Geo_GEOID',
#  'Geo_NAME',
#  'Geo_SUMLEV',
#  'Geo_LOGRECNO',
#  'Geo_COUNTY',
#  'SE_A00002_001',
#  'SE_A00002_002',
#  'SE_A00002_003']

# %%
pop.columns = ['Geo_FIPS',
 'Geo_GEOID',
 'Geo_NAME',
 'Geo_SUMLEV',
 'Geo_LOGRECNO',
 'Geo_COUNTY',
 'Total_Pop',
 'Pop_Den_sqmi',
 'Land_Area']

# %%
pop.head()
# Out:
#   Geo_FIPS     Geo_GEOID          Geo_NAME  Geo_SUMLEV  Geo_LOGRECNO  \
# 0    06001  05000US06001    Alameda County          50            13
# 1    06003  05000US06003     Alpine County          50            14
# 2    06005  05000US06005     Amador County          50            15
# 3    06007  05000US06007      Butte County          50            16
# 4    06009  05000US06009  Calaveras County          50            17
#
#   Geo_COUNTY  Total_Pop  Pop_Den_sqmi    Land_Area
# 0        001    1643700    2229.35100   737.299923
# 1        003       1146       1.55213   738.340335
# 2        005      37829      63.62395   594.571700
# 3        007     227075     138.75900  1636.470186
# 4        009      45235      44.34734  1020.015969

# %%
pop.tail()
# Out:
#    Geo_FIPS     Geo_GEOID         Geo_NAME  Geo_SUMLEV  Geo_LOGRECNO  \
# 53    06107  05000US06107    Tulare County          50            66
# 54    06109  05000US06109  Tuolumne County          50            67
# 55    06111  05000US06111   Ventura County          50            68
# 56    06113  05000US06113      Yolo County          50            69
# 57    06115  05000US06115      Yuba County          50            70
#
#    Geo_COUNTY  Total_Pop  Pop_Den_sqmi    Land_Area
# 53        107     460477      95.44794  4824.378924
# 54        109      53932      24.28395  2220.890352
# 55        111     848112     460.31320  1842.467421
# 56        113     214977     211.85590  1014.732362
# 57        115      75493     119.44790   632.015975

# %% [markdown]
# # descriptive stats

# %% [markdown]
# ## Total Pop

# %%
# mean
pop['Total_Pop'].mean()
# Out:
# 674978.6206896552

# %%
pop['Total_Pop'].describe()
# Out:
# count    5.800000e+01
# mean     6.749786e+05
# std      1.469646e+06
# min      1.146000e+03
# 25%      4.740925e+04
# 50%      1.834385e+05
# 75%      6.839842e+05
# max      1.009805e+07
# Name: Total_Pop, dtype: float64

# %%
# plot it
pop['Total_Pop'].plot.hist(bins=50)

# %% [markdown]
# This plot shows thata majority of the counties have under 200,000. Clearly there is one or two outliers, probably LA County and SF City/County.

# %% [markdown]
# ## Pop Density

# %%
# mean
pop['Pop_Den_sqmi'].mean()
# Out:
# 707.5245303965513

# %%
pop['Pop_Den_sqmi'].describe()
# Out:
# count       58.000000
# mean       707.524530
# std       2497.613195
# min          1.552130
# 25%         25.512882
# 50%        108.265000
# 75%        353.046300
# max      18565.530000
# Name: Pop_Den_sqmi, dtype: float64

# %%
# plot it
pop['Pop_Den_sqmi'].plot.hist(bins=50)

# %% [markdown]
# Interesting, I thought even if the total populations were really skewed that perhaps the size of the county would make the difference less stark. For instance, if a county with a small area had a small population, the density would not be so low.

# %% [markdown]
# ## Land Area

# %%
# mean
pop['Land_Area'].mean()
# Out:
# 2686.0990629539856

# %%
pop['Land_Area'].describe()
# Out:
# count       58.000000
# mean      2686.099063
# std       3102.601880
# min         46.863414
# 25%        959.681358
# 50%       1535.944204
# 75%       3454.928452
# max      20059.898693
# Name: Land_Area, dtype: float64

# %%
pop['Land_Area'].plot.hist(bins=50)

# %% [markdown]
# This plot is a little different from the others. Most counties are below 5,000 square miles, but there is a huge peak around what looks like 1,000 and 1,500 square miles. There is one huge outlier.

# %% [markdown]
# # Sorting
# To make sense of the very skewed plots.

# %% [markdown]
# ## Total pop

# %%
pop_sort = pop.sort_values(by='Total_Pop',ascending=False)

# %%
# Which are the most populous? 
pop_sort[['Geo_NAME','Total_Pop']].head(10)
# Out:
#                  Geo_NAME  Total_Pop
# 18     Los Angeles County   10098052
# 36       San Diego County    3302833
# 29          Orange County    3164182
# 32       Riverside County    2383286
# 35  San Bernardino County    2135413
# 42     Santa Clara County    1922200
# 0          Alameda County    1643700
# 33      Sacramento County    1510023
# 6     Contra Costa County    1133247
# 9           Fresno County     978130

# %%
# What does this look like on a bar graph
pop_sort.head(10).plot.bar(x='Geo_NAME', y='Total_Pop')

# %% [markdown]
# ## Density

# %%
den_sort = pop.sort_values(by='Pop_Den_sqmi',ascending=False)

# %%
den_sort[['Geo_NAME','Pop_Den_sqmi']].head(10)
# Out:
#                 Geo_NAME  Pop_Den_sqmi
# 37  San Francisco County    18565.5300
# 29         Orange County     3991.2410
# 18    Los Angeles County     2488.3120
# 0         Alameda County     2229.3510
# 40      San Mateo County     1707.2550
# 6    Contra Costa County     1580.3600
# 33     Sacramento County     1564.0690
# 42    Santa Clara County     1488.8240
# 36      San Diego County      784.7512
# 43     Santa Cruz County      615.0306

# %%
# plot 
den_sort.head(10).plot.bar(x='Geo_NAME', y='Pop_Den_sqmi')

# %% [markdown]
# ## Land Area

# %%
land_sort = pop.sort_values(by='Land_Area',ascending=False)

# %%
land_sort[['Geo_NAME','Land_Area']].head(10)
# Out:
#                  Geo_NAME     Land_Area
# 35  San Bernardino County  20059.898693
# 13            Inyo County  10180.938253
# 14            Kern County   8132.259800
# 32       Riverside County   7206.558721
# 46        Siskiyou County   6278.767722
# 9           Fresno County   5958.098858
# 53          Tulare County   4824.378924
# 17          Lassen County   4541.185470
# 36       San Diego County   4208.764272
# 12        Imperial County   4176.580475

# %%
# plot
land_sort.head(10).plot.bar(x='Geo_NAME', y='Land_Area')

# %% [markdown]
# # Import geoJSON to do mapping

# %%
import geopandas as gpd

# %%
# upload the counties geojson file from LA times from my data folder
cty = gpd.read_file('../../data/counties-2012.geojson')
cty.head()
# Out:
#             kind external_id       name                   slug  \
# 0  County (2012)       06001    Alameda    alameda-county-2012
# 1  County (2012)       06003     Alpine     alpine-county-2012
# 2  County (2012)       06005     Amador     amador-county-2012
# 3  County (2012)       06007      Butte      butte-county-2012
# 4  County (2012)       06009  Calaveras  calaveras-county-2012
#
#                                 set  \
# 0  /1.0/boundary-set/counties-2012/
# 1  /1.0/boundary-set/counties-2012/
# 2  /1.0/boundary-set/counties-2012/
# 3  /1.0/boundary-set/counties-2012/
# 4  /1.0/boundary-set/counties-2012/
#
#                                             metadata  \
# 0  {'CountyFIPS': '001', 'StateFIPS': '06', 'FIPS...
# 1  {'CountyFIPS': '003', 'StateFIPS': '06', 'FIPS...
# 2  {'CountyFIPS': '005', 'StateFIPS': '06', 'FIPS...
# 3  {'CountyFIPS': '007', 'StateFIPS': '06', 'FIPS...
# 4  {'CountyFIPS': '009', 'StateFIPS': '06', 'FIPS...
#
# ...

# %%
# get info on the dataset
cty.info(verbose=True, null_counts=True)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   kind          58 non-null     object
#  1   external_id   58 non-null     object
#  2   name          58 non-null     object
#  3   slug          58 non-null     object
#  4   set           58 non-null     object
#  5   metadata      58 non-null     object
#  6   resource_uri  58 non-null     object
#  7   geometry      58 non-null     geometry
# dtypes: geometry(1), object(7)
# memory usage: 3.8+ KB

# %% [markdown]
# good, 58 is the number of counties that I know from using the other dataset. All fields are filled too

# %%
# get rid of everything except FIPS and geometry. FIPS in this dataset is the external_id, but in the pop dataset it is called Geo_FIPS
cty=cty[['external_id','geometry']]
cty.head()
# Out:
#   external_id                                           geometry
# 0       06001  MULTIPOLYGON (((-122.31293 37.89733, -122.3108...
# 1       06003  MULTIPOLYGON (((-120.07238 38.70139, -120.0723...
# 2       06005  MULTIPOLYGON (((-121.02729 38.48136, -121.0272...
# 3       06007  MULTIPOLYGON (((-121.63015 39.30567, -121.6784...
# 4       06009  MULTIPOLYGON (((-120.85251 38.00934, -120.8760...

# %%
# need to rename external_id to match pop dataset
cty.columns=['Geo_FIPS','geometry']

# %%
cty.head()
# Out:
#   Geo_FIPS                                           geometry
# 0    06001  MULTIPOLYGON (((-122.31293 37.89733, -122.3108...
# 1    06003  MULTIPOLYGON (((-120.07238 38.70139, -120.0723...
# 2    06005  MULTIPOLYGON (((-121.02729 38.48136, -121.0272...
# 3    06007  MULTIPOLYGON (((-121.63015 39.30567, -121.6784...
# 4    06009  MULTIPOLYGON (((-120.85251 38.00934, -120.8760...

# %%
# what does it look like visually
cty.plot(figsize=(12,10))

# %%
# need to merge pop and cty by the Geo_FIPS field
cty_pop = cty.merge(pop,on="Geo_FIPS")

# %%
# make sure it joined correctly
cty_pop.head()
# Out:
#   Geo_FIPS                                           geometry     Geo_GEOID  \
# 0    06001  MULTIPOLYGON (((-122.31293 37.89733, -122.3108...  05000US06001
# 1    06003  MULTIPOLYGON (((-120.07238 38.70139, -120.0723...  05000US06003
# 2    06005  MULTIPOLYGON (((-121.02729 38.48136, -121.0272...  05000US06005
# 3    06007  MULTIPOLYGON (((-121.63015 39.30567, -121.6784...  05000US06007
# 4    06009  MULTIPOLYGON (((-120.85251 38.00934, -120.8760...  05000US06009
#
#            Geo_NAME  Geo_SUMLEV  Geo_LOGRECNO Geo_COUNTY  Total_Pop  \
# 0    Alameda County          50            13        001    1643700
# 1     Alpine County          50            14        003       1146
# 2     Amador County          50            15        005      37829
# 3      Butte County          50            16        007     227075
# 4  Calaveras County          50            17        009      45235
#
#    Pop_Den_sqmi    Land_Area
# 0    2229.35100   737.299923
# 1       1.55213   738.340335
# ...

# %%
# chloropleth map of the counties' population density 
cty_pop.plot(figsize=(12,10), 
             column='Pop_Den_sqmi',
             legend=True,
             scheme='NaturalBreaks')

# %%
cty_pop.plot(figsize=(12,10), 
             column='Pop_Den_sqmi',
             legend=True,
             scheme='equal_interval')

# %%
cty_pop.plot(figsize=(12,10), 
             column='Pop_Den_sqmi',
             legend=True,
             scheme='quantiles')

# %% [markdown]
# wow, the three types of schemes are drastically different. In this case equal interval is basically useless.

# %%
# now I'll look at total population
cty_pop.plot(figsize=(12,10), 
             column='Total_Pop',
             legend=True,
             scheme='NaturalBreaks')

# %%
cty_pop.plot(figsize=(12,10), 
             column='Total_Pop',
             legend=True,
             scheme='equal_interval')

# %%
cty_pop.plot(figsize=(12,10), 
             column='Total_Pop',
             legend=True,
             scheme='quantiles')

# %% [markdown]
# Again, equal interval is kind of useless. However, natural breaks and quantiles show very different stories. Natural breaks clearly shows LA County is the most populous, and that SoCal and the Bay Area are basically the only higer-populated areas. But the quantiles version shows the whole southland, the bay, the Central Coast, and the Central Valley are pretty populated.
